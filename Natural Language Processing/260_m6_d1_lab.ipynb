# %%
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer

# Wrap LinearSVC with NLTK's SklearnClassifier
nltk_svm_classifier = SklearnClassifier(LinearSVC(dual=True))

# Define a simple function to extract NLTK-style word presence features from raw text
def document_features_for_nltk(document):
    # Convert to lowercase and split into words (simple tokenization)
    words = document.lower().split()
    # Create a dictionary where keys are words and values are True (indicating presence)
    return {word: True for word in words}

nltk_training_data = [(document_features_for_nltk(X_train[i]), y_train[i]) for i in range(len(X_train))]

print("Training NLTK SVM Classifier (with word presence features)...")
nltk_svm_classifier.train(nltk_training_data)
print("Training complete.")

tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1,2), min_df=2)
X_train_transformed = tfidf_vectorizer.fit_transform(X_train)
# Out:
# Training NLTK SVM Classifier (with word presence features)...
# Training complete.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, accuracy_score

nb_model = Pipeline([
    ("tfidf", TfidfVectorizer(stop_words='english',
                            ngram_range=(1,2),
                            min_df=2)),
    ("clf", MultinomialNB())
])

nb_model.fit(X_train, y_train)

nb_pred = nb_model.predict(X_test)
print("Accuracy (Naive Bayes):", accuracy_score(y_test, nb_pred))
print(classification_report(y_test, nb_pred))


nltk_test_data_features = [document_features_for_nltk(text) for text in X_test]

# Predict using the NLTK SVM classifier
nltk_svm_pred = [nltk_svm_classifier.classify(features) for features in nltk_test_data_features]

print("\nAccuracy (NLTK SVM):", accuracy_score(y_test, nltk_svm_pred))
print(classification_report(y_test, nltk_svm_pred))
# Out:
# Accuracy (Naive Bayes): 0.794
#               precision    recall  f1-score   support
#
#          neg       0.80      0.79      0.79       250
#          pos       0.79      0.80      0.80       250
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.79      0.79       500
# weighted avg       0.79      0.79      0.79       500
#
#
# Accuracy (NLTK SVM): 0.856
#               precision    recall  f1-score   support
#
#          neg       0.86      0.85      0.86       250
#          pos       0.85      0.86      0.86       250
#
#     accuracy                           0.86       500
#    macro avg       0.86      0.86      0.86       500
# weighted avg       0.86      0.86      0.86       500

# %%
from nltk.corpus import movie_reviews
import random
nltk.download('movie_reviews')
documents = [(movie_reviews.raw(fid), cat)
for cat in movie_reviews.categories()
for fid in movie_reviews.fileids(cat)]
random.shuffle(documents)
texts = [d for (d, c) in documents]
labels = [c for (d, c) in documents]
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.

# %%
X_train, X_test, y_train, y_test = train_test_split(
texts, labels, test_size=0.25, random_state=42, stratify=labels
)

# %%
svm_model = Pipeline([
("tfidf", TfidfVectorizer(stop_words='english',
ngram_range=(1,2),
min_df=2)),
("clf", LinearSVC())
])

# %%
svm_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(min_df=2, ngram_range=(1, 2),
#                                  stop_words='english')),
#                 ('clf', LinearSVC())])

# %%
pred = svm_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#          neg       0.86      0.81      0.84       250
#          pos       0.82      0.87      0.84       250
#
#     accuracy                           0.84       500
#    macro avg       0.84      0.84      0.84       500
# weighted avg       0.84      0.84      0.84       500

# %%
sample = ["This movie was absolutely fantastic!"]
print(svm_model.predict(sample))
# Out:
# ['pos']

# %%
from sklearn.naive_bayes import MultinomialNB

nb_model = Pipeline([
    ("tfidf", TfidfVectorizer(stop_words='english',
                            ngram_range=(1,2),
                            min_df=2)),
    ("clf", MultinomialNB())
])

nb_model.fit(X_train, y_train)

nb_pred = nb_model.predict(X_test)
print("Accuracy (Naive Bayes):", accuracy_score(y_test, nb_pred))
print(classification_report(y_test, nb_pred))
# Out:
# Accuracy (Naive Bayes): 0.794
#               precision    recall  f1-score   support
#
#          neg       0.80      0.79      0.79       250
#          pos       0.79      0.80      0.80       250
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.79      0.79       500
# weighted avg       0.79      0.79      0.79       500
